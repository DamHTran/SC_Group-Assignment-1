# %% [markdown]
# # Import relevant libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()

# %% [markdown]
# # Import data

# %%
data = pd.read_csv('D:/Projects/ISM/DataScience/SC/analytics_fundamentals/assignment_1_data.csv')

# %% [markdown]
# # Data cleaning

# %% [markdown]
# # EDA

# %%
data.head()
# Out:
#    ANSWERED  INCOME  FEMALE  AGE  JOB  NUM_DEPENDENTS  RENT  OWN_RES  NEW_CAR  \
# 0         1   13904       0   29    0               1     1        0        0
# 1         0   14754       0   25    1               1     0        1        0
# 2         1   37945       0   62    2               1     0        0        1
# 3         0   12504       0   32    2               1     0        1        0
# 4         0   12423       0   57    1               2     0        0        1
#
#    CHK_ACCT  SAV_ACCT  NUM_ACCTS  MOBILE  PRODUCT
# 0         0         2          4       1        0
# 1         3         0          3       1        0
# 2         1         0          4       0        2
# 3         1         0          1       0        0
# 4         2         1          4       0        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29504 entries, 0 to 29503
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ANSWERED        29504 non-null  int64
#  1   INCOME          29504 non-null  int64
#  2   FEMALE          29504 non-null  int64
#  3   AGE             29504 non-null  int64
#  4   JOB             29504 non-null  int64
#  5   NUM_DEPENDENTS  29504 non-null  int64
#  6   RENT            29504 non-null  int64
#  7   OWN_RES         29504 non-null  int64
#  8   NEW_CAR         29504 non-null  int64
#  9   CHK_ACCT        29504 non-null  int64
#  10  SAV_ACCT        29504 non-null  int64
#  11  NUM_ACCTS       29504 non-null  int64
#  12  MOBILE          29504 non-null  int64
#  13  PRODUCT         29504 non-null  int64
# dtypes: int64(14)
# memory usage: 3.2 MB

# %%
data.describe()
# Out:
#            ANSWERED         INCOME        FEMALE           AGE           JOB  \
# count  29504.000000   29504.000000  29504.000000  29504.000000  29504.000000
# mean       0.546062   33772.511795      0.054671     34.792232      1.915537
# std        0.497882   29379.441396      0.227340     11.266942      0.658561
# min        0.000000    1417.000000      0.000000     19.000000      0.000000
# 25%        0.000000   13578.000000      0.000000     26.000000      2.000000
# 50%        1.000000   23418.500000      0.000000     32.000000      2.000000
# 75%        1.000000   41763.000000      0.000000     40.000000      2.000000
# max        1.000000  161107.000000      1.000000     74.000000      3.000000
#
#        NUM_DEPENDENTS          RENT       OWN_RES       NEW_CAR      CHK_ACCT  \
# count    29504.000000  29504.000000  29504.000000  29504.000000  29504.000000
# mean         1.141133      0.211158      0.681297      0.241222      1.462717
# std          0.348165      0.408137      0.465981      0.427832      1.232531
# min          1.000000      0.000000      0.000000      0.000000      0.000000
# 25%          1.000000      0.000000      0.000000      0.000000      0.000000
# 50%          1.000000      0.000000      1.000000      0.000000      1.000000
# 75%          1.000000      0.000000      1.000000      0.000000      3.000000
# max          2.000000      1.000000      1.000000      1.000000      3.000000
#
#            SAV_ACCT     NUM_ACCTS        MOBILE       PRODUCT
# count  29504.000000  29504.000000  29504.000000  29504.000000
# mean       0.963971      2.347614      0.092259      1.528369
# std        1.489284      1.200262      0.289396      1.621094
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.000000      0.000000      0.000000
# 50%        0.000000      2.000000      0.000000      1.000000
# 75%        2.000000      3.000000      0.000000      3.000000
# max        4.000000      4.000000      1.000000      4.000000

# %% [markdown]
# ## ANSWERED

# %%
data['ANSWERED'].value_counts(normalize=True) * 100
# Out:
# 1    54.606155
# 0    45.393845
# Name: ANSWERED, dtype: float64

# %% [markdown]
# ## INCOME, AGE, NUM_DEPENDENTS , NUM_ACCTS

# %%
# Histograms for distribution
numeric_columns = ['INCOME', 'AGE', 'NUM_DEPENDENTS', 'NUM_ACCTS']
data[numeric_columns].hist(bins=15, figsize=(10, 6))
plt.suptitle('Distribution of Numeric Columns')
plt.show()

# %% [markdown]
# ## FEMALE, JOB, RENT, OWN_RES, NEW_CAR, CHK_ACCT, SAV_ACCT, MOBILE, PRODUCT

# %%
categorical_columns = ['FEMALE', 'JOB', 'RENT', 'OWN_RES', 'NEW_CAR', 'CHK_ACCT', 'SAV_ACCT', 'MOBILE', 'PRODUCT']
for col in categorical_columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(data[col])
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# # CORRELATION RELATIONSHIP

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr().round(3), annot=True, fmt=".3f", cmap='coolwarm')  # Rounds to 3 decimal places
plt.title('Correlation Matrix')
plt.show()
